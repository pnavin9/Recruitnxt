# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import re
import optuna
from optuna import Trial, visualization
from sklearn.model_selection import StratifiedKFold, KFold,cross_val_predict,cross_val_score,cross_validate
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.metrics import f1_score


# Load train and test data
train_data = pd.read_csv('/kaggle/input/primal2-0/final_train.csv')
test_data = pd.read_csv('/kaggle/input/primal2-0/final_test.csv')

# Concatenate train and test data for preprocessing
combined_data = pd.concat([train_data, test_data], ignore_index=True)

value_mapping = {
    'a': 6,  # Example: 10 lakhs
}
# Replace values in the 'ticket size' column using the mapping
combined_data['Previous_Organizations'] = test_data['Previous_Organizations'].replace(value_mapping)

# Drop specified columns
combined_data.drop(columns=['Designation', 'DOJ', 'R_District', 'B_District', 'Company_1', 'Company_2', 'Skill'], inplace=True)

# Replace Graduation and Qualification values
combined_data['Graduation'] = combined_data['Graduation'].fillna(0).map({'full time': 1, 'part time': 0, 0: 0})
combined_data['Qualification'] = combined_data['Qualification'].map({'graduate': 2, 'under graduate': 1, 'post graduate': 3, 'others': 0, 'diploma holders': 4}).fillna(-1)

# Set 'Previous_Organizations' as type int, treating NaN as 0
combined_data['Previous_Organizations'] = combined_data['Previous_Organizations'].fillna(0).astype(int)

# One-hot encoding for categorical variables
columns_to_encode = ['Industry', 'Source', 'Department', 'R_Region', 'B_Region']
combined_data_encoded = pd.get_dummies(combined_data, columns=columns_to_encode)

# Create indicator variables for states
states = list(combined_data['R_State']) + list(combined_data['B_State'])
for state in states:
    combined_data_encoded[state] = ((combined_data['R_State'] == state) | (combined_data['B_State'] == state)).astype(int)

# Drop 'R_State' and 'B_State'
combined_data_encoded.drop(columns=['R_State', 'B_State', 'Unnamed: 0'], inplace=True)
combined_data_encoded.columns = [re.sub(r'\W+', '_', col) for col in combined_data_encoded.columns]

# Separate back into train and test data
train_data_processed = combined_data_encoded.iloc[:len(train_data)]
test_data_processed = combined_data_encoded.iloc[len(train_data):].drop(columns='Performance')  # Assuming 'Target' is the target column

# %%
df_all = train_data_processed
df_test = test_data_processed
#df_submission = pd.read_csv("/kaggle/input/sample/sample.csv")

# %%
X = df_all.drop(labels=['CandidateID','Performance'],axis=1,inplace=False).copy()
y = df_all['Performance'].values
X_test = df_test.drop(labels=['CandidateID'],axis=1,inplace=False).copy()
random_seed = 0

# %%
encoder = OneHotEncoder()
all_encoded = encoder.fit_transform(pd.concat([X,X_test]))
#X = all_encoded[0:len(X)]
#X_test = all_encoded[len(X):]
X = all_encoded.tocsr()[0:len(X)]
X_test = all_encoded [len(df_all):]

# %%
df_all['Performance'].value_counts()
# Out:
# Performance
# 0.0    450
# 1.0    295
# Name: count, dtype: int64

# %%
X = df_all.drop(labels=['CandidateID','Performance'],axis=1,inplace=False).copy()
y = df_all['Performance'].values
X_test = df_test.drop(labels=['CandidateID'],axis=1,inplace=False).copy()
random_seed = 0

# %%
encoder = OneHotEncoder()
all_encoded = encoder.fit_transform(pd.concat([X,X_test]))
#X = all_encoded[0:len(X)]
#X_test = all_encoded[len(X):]
X = all_encoded.tocsr()[0:len(X)]
X_test = all_encoded [len(df_all):]

# %%
from sklearn.impute import SimpleImputer
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import log_loss
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

def objective(trial, data=X, target=y):
    param_space = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),  # Number of weak learners
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
        'algorithm': trial.suggest_categorical('algorithm', ['SAMME.R', 'SAMME'])  # Algorithm type
        }

    k = 5
    seed_list = [0]
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=random_seed)
    oof = np.zeros((len(df_all), 2))
    score_list = []
    fold = 1

    splits = list(kf.split(X, y))
    for train_idx, val_idx in splits:
        X_train, X_val = X[train_idx, :], X[val_idx, :]
        y_train, y_val = y[train_idx], y[val_idx]

        val_preds_list = []

        for seed in seed_list:
            # fit and run model
            imputer = SimpleImputer(strategy='mean')
            Xtrain_imputed = imputer.fit_transform(X_train)
            Xval_imputed = imputer.transform(X_val)
            model = AdaBoostClassifier(**param_space, random_state=0)
            model.fit(Xtrain_imputed,y_train)

            val_preds_list.append(model.predict_proba(Xval_imputed))

        oof[val_idx] = np.mean(val_preds_list, axis=0)
        score = f1_score(y_val, np.argmax(oof[val_idx], axis=1))
        score_list.append(score)
        fold += 1

    cv_f1 = np.mean(score_list)

    return cv_f1

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective,n_trials= 100)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2024-04-11 13:42:43,541] A new study created in memory with name: no-name-ad080fa1-e9df-4f23-9394-c1ece2e544c9
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:43:17,821] Trial 0 finished with value: 0.03155737704918033 and parameters: {'n_estimators': 626, 'learning_rate': 0.006941259583685907, 'algorithm': 'SAMME'}. Best is trial 0 with value: 0.03155737704918033.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:44:01,098] Trial 1 finished with value: 0.088 and parameters: {'n_estimators': 793, 'learning_rate': 0.0018428294458776035, 'algorithm': 'SAMME'}. Best is trial 1 with value: 0.088.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:44:24,441] Trial 2 finished with value: 0.13411104715858943 and parameters: {'n_estimators': 426, 'learning_rate': 0.0958192768586831, 'algorithm': 'SAMME'}. Best is trial 2 with value: 0.13411104715858943.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:44:58,088] Trial 3 finished with value: 0.088 and parameters: {'n_estimators': 615, 'learning_rate': 0.002152108039423498, 'algorithm': 'SAMME'}. Best is trial 2 with value: 0.13411104715858943.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:45:33,644] Trial 4 finished with value: 0.4184936746440685 and parameters: {'n_estimators': 639, 'learning_rate': 0.050391997254397546, 'algorithm': 'SAMME.R'}. Best is trial 4 with value: 0.4184936746440685.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:45:51,994] Trial 5 finished with value: 0.1704400363869231 and parameters: {'n_estimators': 325, 'learning_rate': 0.0029017616453580726, 'algorithm': 'SAMME.R'}. Best is trial 4 with value: 0.4184936746440685.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:46:44,917] Trial 6 finished with value: 0.45975021514382064 and parameters: {'n_estimators': 954, 'learning_rate': 0.1385335760449826, 'algorithm': 'SAMME.R'}. Best is trial 6 with value: 0.45975021514382064.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:46:55,087] Trial 7 finished with value: 0.0 and parameters: {'n_estimators': 181, 'learning_rate': 0.005659912365403725, 'algorithm': 'SAMME'}. Best is trial 6 with value: 0.45975021514382064.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:47:33,131] Trial 8 finished with value: 0.43735382399861483 and parameters: {'n_estimators': 686, 'learning_rate': 0.07853858597298755, 'algorithm': 'SAMME.R'}. Best is trial 6 with value: 0.45975021514382064.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:47:53,952] Trial 9 finished with value: 0.3385533070995902 and parameters: {'n_estimators': 372, 'learning_rate': 0.02203643001309318, 'algorithm': 'SAMME.R'}. Best is trial 6 with value: 0.45975021514382064.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13:48:47,418] Trial 10 finished with value: 0.46454570841951515 and parameters: {'n_estimators': 972, 'learning_rate': 0.6377605098228544, 'algorithm': 'SAMME.R'}. Best is trial 10 with value: 0.46454570841951515.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 13
 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:35:26,778] Trial 85 finished with value: 0.21358238423515333 and parameters: {'n_estimators': 224, 'learning_rate': 0.003339218090629174, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:35:50,189] Trial 86 finished with value: 0.43724348504999055 and parameters: {'n_estimators': 410, 'learning_rate': 0.6736743120669495, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:36:07,404] Trial 87 finished with value: 0.46238439049432306 and parameters: {'n_estimators': 299, 'learning_rate': 0.4096416833911569, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:36:38,163] Trial 88 finished with value: 0.4546618877518668 and parameters: {'n_estimators': 545, 'learning_rate': 0.9815501834578212, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:36:58,379] Trial 89 finished with value: 0.4571740225749812 and parameters: {'n_estimators': 352, 'learning_rate': 0.57848945554615, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:37:13,181] Trial 90 finished with value: 0.45054464914930026 and parameters: {'n_estimators': 254, 'learning_rate': 0.7727839914504003, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:38:03,940] Trial 91 finished with value: 0.4814093550106232 and parameters: {'n_estimators': 903, 'learning_rate': 0.5061223416347788, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:38:57,374] Trial 92 finished with value: 0.4549250262822996 and parameters: {'n_estimators': 946, 'learning_rate': 0.22026196205855356, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:39:47,988] Trial 93 finished with value: 0.4265577649549587 and parameters: {'n_estimators': 902, 'learning_rate': 0.025154990292980677, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:40:05,195] Trial 94 finished with value: 0.4289524500977958 and parameters: {'n_estimators': 301, 'learning_rate': 0.5102089865389647, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:40:54,543] Trial 95 finished with value: 0.4634072329789257 and parameters: {'n_estimators': 880, 'learning_rate': 0.8184828682742016, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:41:38,484] Trial 96 finished with value: 0.4393347897657005 and parameters: {'n_estimators': 794, 'learning_rate': 0.6664757308936885, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:41:44,296] Trial 97 finished with value: 0.46500243386988754 and parameters: {'n_estimators': 101, 'learning_rate': 0.40771088191789734, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:42:19,624] Trial 98 finished with value: 0.3486412274421927 and parameters: {'n_estimators': 642, 'learning_rate': 0.5743405245662433, 'algorithm': 'SAMME'}. Best is trial 63 with value: 0.4899547663855631.
# /tmp/ipykernel_18/1544049593.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),  # Controls step size
# [I 2024-04-11 14:43:10,456] Trial 99 finished with value: 0.44091758561924815 and parameters: {'n_estimators': 917, 'learning_rate': 0.12137758195982258, 'algorithm': 'SAMME.R'}. Best is trial 63 with value: 0.4899547663855631.
# Number of finished trials: 100
# Best trial: {'n_estimators': 948, 'learning_rate': 0.628581538464075, 'algorithm': 'SAMME.R'}

# %%
param_space = study.best_trial.params
imputer = SimpleImputer(strategy='mean')
Xtrain_imputed = imputer.fit_transform(X)
Xtest_imputed = imputer.transform(X_test)
model = AdaBoostClassifier(**param_space, random_state=0)
model.fit(Xtrain_imputed,y)
# Out:
# AdaBoostClassifier(learning_rate=0.628581538464075, n_estimators=948,
#                    random_state=0)

# %%
df_test[['class1','class2']] = model.predict_proba(Xtest_imputed)
submission = df_test[['CandidateID','class1','class2']]
submission.to_csv('catboost_nd.csv')

# %%
submission
# Out:
#     CandidateID    class1    class2
# 745     emp0521  0.494564  0.505436
# 746     emp0613  0.499192  0.500808
# 747     emp0136  0.492114  0.507886
# 748     emp0351  0.507313  0.492687
# 749     emp0049  0.505372  0.494628
# ..          ...       ...       ...
# 927     emp0401  0.499666  0.500334
# 928     emp0408  0.511882  0.488118
# 929     emp0248  0.502990  0.497010
# 930     emp0148  0.496242  0.503758
# 931     emp0422  0.495292  0.504708
#
# [187 rows x 3 columns]
